# %% [markdown]
# # Tarea 02 — Carga de Datos con Pandas
#
# **Instrucciones:** Completa cada celda de código con tu respuesta.
# Usarás el dataset de Iris disponible en la URL indicada.

# %%
import pandas as pd

# %% [markdown]
# ---
# ## Parte 1 — Cargar y explorar datos

# %% [markdown]
# **P1.** Carga el dataset de Iris desde la siguiente URL y guárdalo en una variable llamada `df`.
# URL: `https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv`

# %%
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"

# Tu respuesta aquí
df = pd.read_csv(url)

# %% [markdown]
# **P2.** Muestra las primeras 5 filas del DataFrame.

# %%
# Tu respuesta aquí
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# **P3.** Usa `.info()` para ver los tipos de columnas y si hay valores nulos.
# Luego usa `.describe()` para ver el resumen estadístico. ¿Cuántas filas tiene el dataset?

# %%
# Tu respuesta aquí
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# **Respuesta:** El dataset tiene 150 filas.

# %% [markdown]
# ---
# ## Parte 2 — Selección y filtrado

# %% [markdown]
# **P4.** Selecciona solo las columnas `sepal_length` y `species` e imprime las primeras 5 filas.

# %%
# Tu respuesta aquí
df[["sepal_length", "species"]].head()
# Out:
#    sepal_length species
# 0           5.1  setosa
# 1           4.9  setosa
# 2           4.7  setosa
# 3           4.6  setosa
# 4           5.0  setosa

# %% [markdown]
# **P5.** Filtra el DataFrame para quedarte solo con las flores de la especie `virginica`.
# ¿Cuántas filas tiene ese subconjunto?

# %%
# Tu respuesta aquí
df_virginica = df[df["species"] == "virginica"]

len(df_virginica)
# Out:
# 50

# %% [markdown]
# **P6.** Filtra las filas donde `petal_length` sea mayor a 5.0. Imprime cuántas filas cumplen esa condición.

# %%
# Tu respuesta aquí
len(df[df["petal_length"] > 5.0])
# Out:
# 42

# %% [markdown]
# ---
# ## Parte 3 — Guardar datos

# %% [markdown]
# **P7.** Guarda el subconjunto de `virginica` (de P5) en un archivo CSV llamado `virginica.csv` en la carpeta `output/`.
# No incluyas el índice en el archivo guardado.

# %%
import os
os.makedirs("output", exist_ok=True)

# Tu respuesta aquí
df_virginica.to_csv("output/virginica.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 import os
#       2 os.makedirs("output", exist_ok=True)
#       3
#       4 # Tu respuesta aquí
# ----> 5 df_virginica = df[df["species"] == 2]
#       6 df_virginica.to_csv("output/virginica.csv", index=False)
#
# NameError: name 'df' is not defined

# %% [markdown]
# **P8.** Carga de nuevo el archivo `output/virginica.csv` y verifica que tiene el número correcto de filas usando `.shape`.

# %%
# Tu respuesta aquí
df_verificado = pd.read_csv("output/virginica.csv")

df_verificado.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Tu respuesta aquí
# ----> 2 df_verificado = pd.read_csv("output/virginica.csv")
#       3
#       4 df_verificado.shape
#
# File c:\Users\Alejandro\Desktop\CIENCIA DE DATOS\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Alejandro\Desktop\CIENCIA DE DATOS\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\Alejandro\Desktop\CIENCIA DE DATOS\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Alejandro\Desktop\CIENCIA DE DATOS\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\Alejandro\Desktop\CIENCIA DE DATOS\venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/virginica.csv'
